# %%
import numpy as hp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("C:/Users/nawaz/Desktop/tasks/loan.csv")
# Out:
# c:\users\anand me\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# ...

# %%
df.int_rate
# Out:
# 0        10.65%
# 1        15.27%
# 2        15.96%
# 3        13.49%
# 4        12.69%
#           ...
# 39712     8.07%
# 39713    10.28%
# 39714     8.07%
# 39715     7.43%
# 39716    13.75%
# Name: int_rate, Length: 39717, dtype: object

# %%
df.installment
# Out:
# 0        162.87
# 1         59.83
# 2         84.33
# 3        339.31
# 4         67.79
#           ...
# 39712     78.42
# 39713    275.38
# 39714    156.84
# 39715    155.38
# 39716    255.43
# Name: installment, Length: 39717, dtype: float64

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
df.tail(200)
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 39517  172644     172641      12000        12000       156.680000   36 months
# 39518  171298     171282       7000         7000      1000.000000   36 months
# 39519  171220     170849      20000        20000       310.979002   36 months
# 39520  170929     170462       9000         9000      1125.000000   36 months
# 39521  170528     165069      12000        12000       656.690000   36 months
# ...       ...        ...        ...          ...              ...         ...
# 39712   92187      92174       2500         2500      1075.000000   36 months
# 39713   90665      90607       8500         8500       875.000000   36 months
# 39714   90395      90390       5000         5000      1325.000000   36 months
# 39715   90376      89243       5000         5000       650.000000   36 months
# 39716   87023      86999       7500         7500       800.000000   36 months
#
# ...

# %%
plt.boxplot(df['funded_amnt_inv'])
plt.show()

# %%
plt.hist(df['funded_amnt_inv'])
plt.show()

# %%
plt.boxplot(df['installment'])
plt.show()

# %%
plt.boxplot(df['funded_amnt'])
plt.xlabel('loan_amnt')
plt.ylabel('discount')
plt.xlim(20,50)
plt.ylim(100,50)
plt.show()

# %%
plt.boxplot(df['tot_hi_cred_lim'])
plt.show()
# Out:
# c:\users\anand me\appdata\local\programs\python\python38\lib\site-packages\matplotlib\cbook\__init__.py:1316: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# c:\users\anand me\appdata\local\programs\python\python38\lib\site-packages\matplotlib\cbook\__init__.py:1323: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# c:\users\anand me\appdata\local\programs\python\python38\lib\site-packages\matplotlib\cbook\__init__.py:1331: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# c:\users\anand me\appdata\local\programs\python\python38\lib\site-packages\matplotlib\cbook\__init__.py:1332: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],

# %%
plt.boxplot(df['id'])
plt.show()

# %%
plt.boxplot(df['member_id'])
plt.show()

# %%
plt.hist(df['member_id'])
plt.show()

# %%
plt.hist(['grade'])
plt.show()

# %%
plt.hist(['term','num_tl_90g_dpd_24m'])
plt.show()

# %%
plt.scatter(df['term'],df['term'])
plt.show()

# %%
plt.subplot(1,2,1)
plt.boxplot(df['funded_amnt_inv'])
plt.title("term")
plt.xlabel("amount")
plt.ylabel("salary")

plt.subplot(1,2,2)
plt.boxplot(df['funded_amnt_inv'])
plt.ylabel('log')
plt.show()

# %%
sns.barplot(x='funded_amnt_inv',y='grade',data=df)
plt.show()

# %%
sns.barplot(x='loan_amnt',y='grade',data=df)
plt.show()

# %%
sns.barplot(x='term',y='num_tl_90g_dpd_24m',data=df)
plt.show()

# %%
sns.barplot(x='loan_amnt',y='num_tl_90g_dpd_24m',data=df)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv("E:/khaja/loan1.csv")
plt.figure(figsize=(10,8))
sns.distplot(df['id'])
plt.show()
# Out:
# c:\users\anand me\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df=pd.read_csv("E:/khaja/loan1.csv")
plt.figure(figsize=(10,8))
sns.distplot(df['member_id'])
plt.show()
# Out:
# c:\users\anand me\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sns.distplot(df['installment'])

# %%
sns.distplot(df['id'])

# %%
sns.distplot(df['member_id'])

# %%
sns.distplot(df['num_tl_90g_dpd_24m'])
# Out:
# c:\users\anand me\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:200: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# c:\users\anand me\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\users\anand me\appdata\local\programs\python\python38\lib\site-packages\numpy\lib\histograms.py:908: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges

# %%
plt.subplot(1,2,1)
plt.title("nan")
sns.jointplot('member_id','installment',df)

# %%
plt.subplot(1,2,1)
plt.title("nan")
sns.jointplot('member_id','id',df)

# %%
sns.jointplot('id', 'installment', df, kind="hex", color="g")

# %%
sns.jointplot('member_id', 'installment', df, kind="hex", color="k")
